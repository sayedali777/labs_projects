# %% [markdown]
# <img src="../assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Introduction to `pandas`
#
# ---

# %% [markdown]
# ### About
# `pandas` is the most popular python package for managing datasets and is used extensively by data scientists.
#
# ### Learning Objectives
# - Explore the characteristics of a dataset at a high level with `pandas`.
#
# ### Notebook Guide
# An exercise in practising:
#
# - Reading data with `pandas`
# - Exploring and manipulating data with `pandas`
#     - Column operations
#     - Filtering
#     - Sorting
#     - Writing data

# %% [markdown]
# # Scenario
#
# You're an analyst working for CoolBricks - a new toy company who wants to compete with LEGO by producing their own bricks and sets. To better understand what kind of sets to create and at what price points, you are tasked with analyzing LEGO's catalogue over time.
#
# The data comes from Kaggle: [https://www.kaggle.com/datasets/alexracape/lego-sets-and-prices-over-time](https://www.kaggle.com/datasets/alexracape/lego-sets-and-prices-over-time)
#
# We are going to use `pandas` to read and explore this data.
#
# ### Business question
#
# What is the biggest set we could build (in terms of number of pieces) and what sort of price would we want to charge?

# %% [markdown]
# #### 1. Import `pandas` and read in the LEGO dataset

# %%
import pandas as pd

legoset = pd.read_csv('./data/lego.csv')

legoset.head()
# Out:
#   Set_ID            Name  Year      Theme Theme_Group   Subtheme Category  \
# 0   75-1   PreSchool Set  1975  PreSchool  Pre-school        NaN   Normal
# 1   77-1   PreSchool Set  1975  PreSchool  Pre-school        NaN   Normal
# 2  077-1  Pre-School Set  1975      Duplo  Pre-school        NaN   Normal
# 3   78-1   PreSchool Set  1975  PreSchool  Pre-school        NaN   Normal
# 4   78-3       Basic Set  1975  Samsonite     Vintage  Basic set   Normal
#
#          Packaging  Num_Instructions     Availability  Pieces  Minifigures  \
# 0  {Not specified}                 0  {Not specified}    16.0          NaN
# 1  {Not specified}                 0  {Not specified}    20.0          NaN
# 2  {Not specified}                 0  {Not specified}    21.0          NaN
# 3  {Not specified}                 0  {Not specified}    32.0          NaN
# 4              Box                 0  {Not specified}   330.0          NaN
#
#    Owned  Rating  USD_MSRP  Total_Quantity  Current_Price
# 0   10.0     0.0       NaN             NaN            NaN
# 1   11.0     0.0       NaN             NaN            NaN
# 2   10.0     0.0       NaN             0.0            NaN
# 3    8.0     0.0       NaN             NaN            NaN
# 4   10.0     0.0       NaN             0.0            NaN

# %% [markdown]
# #### 2. So we can focus on just the columns that help answer the question, select only the following columns into a new `DataFrame` variable:
#
# - name
# - theme
# - number of pieces
# - retail price (USD_MSRP)

# %%
lego_new = legoset[['Name','Theme','Pieces','USD_MSRP']]

lego_new
# Out:
#                           Name      Theme  Pieces  USD_MSRP
# 0                PreSchool Set  PreSchool    16.0       NaN
# 1                PreSchool Set  PreSchool    20.0       NaN
# 2               Pre-School Set      Duplo    21.0       NaN
# 3                PreSchool Set  PreSchool    32.0       NaN
# 4                    Basic Set  Samsonite   330.0       NaN
# ...                        ...        ...     ...       ...
# 14931        Creeper Key Chain       Gear     NaN      5.99
# 14932          Steve Key Chain       Gear     NaN      5.99
# 14933         Piglin Key Chain       Gear     NaN      5.99
# 14934   Fennec Shand Key Chain       Gear     NaN      5.99
# 14935  Scout Trooper Key Chain       Gear     NaN      5.99
#
# [14936 rows x 4 columns]

# %% [markdown]
# #### 3. How many sets have a price greater than $100?

# %%
lego_new[lego_new['USD_MSRP'] > 100]
# Out:
#                             Name          Theme  Pieces  USD_MSRP
# 4769     Imperial Star Destroyer      Star Wars  3096.0    269.99
# 5324            3-Seat Playtable           Gear     NaN    249.99
# 5973               Death Star II      Star Wars  3441.0    269.99
# 5974                 Sandcrawler      Star Wars  1669.0    139.99
# 6256          Cargo Train Deluxe           City   856.0    149.99
# ...                          ...            ...     ...       ...
# 14896  Temple of the Golden Idol  Indiana Jones  1545.0    149.99
# 14900  Monkie Kid's Team Hideout     Monkie Kid  1582.0    139.99
# 14901     Monkey King Ultra Mech     Monkie Kid  1705.0    159.99
# 14905  Dragon of the East Palace     Monkie Kid  2364.0    189.99
# 14907      Lunar New Year Parade       Seasonal  1653.0    129.99
#
# [380 rows x 4 columns]

# %% [markdown]
# #### 4. What are the top 10 sets with the highest number of pieces?

# %%
lego_new.sort_values('Pieces', ascending= False)
# Out:
#                           Name      Theme   Pieces  USD_MSRP
# 13559                World Map        Art  11695.0    249.99
# 13946             Eiffel Tower      Icons  10001.0    629.99
# 13449                  Titanic      Icons   9090.0    679.99
# 12942                Colosseum      Icons   9036.0    549.99
# 11928        Millennium Falcon  Star Wars   7541.0    849.99
# ...                        ...        ...      ...       ...
# 14931        Creeper Key Chain       Gear      NaN      5.99
# 14932          Steve Key Chain       Gear      NaN      5.99
# 14933         Piglin Key Chain       Gear      NaN      5.99
# 14934   Fennec Shand Key Chain       Gear      NaN      5.99
# 14935  Scout Trooper Key Chain       Gear      NaN      5.99
#
# [14936 rows x 4 columns]

# %% [markdown]
# #### 5. Create a new column to measure "price per piece", which should be the price (USD_MSRP) divided by the number of pieces

# %%
lego_new['price per piece'] = lego_new['USD_MSRP'] / lego_new['Pieces']

# %%
lego_new
# Out:
#                           Name      Theme  Pieces  USD_MSRP  price per piece
# 0                PreSchool Set  PreSchool    16.0       NaN              NaN
# 1                PreSchool Set  PreSchool    20.0       NaN              NaN
# 2               Pre-School Set      Duplo    21.0       NaN              NaN
# 3                PreSchool Set  PreSchool    32.0       NaN              NaN
# 4                    Basic Set  Samsonite   330.0       NaN              NaN
# ...                        ...        ...     ...       ...              ...
# 14931        Creeper Key Chain       Gear     NaN      5.99              NaN
# 14932          Steve Key Chain       Gear     NaN      5.99              NaN
# 14933         Piglin Key Chain       Gear     NaN      5.99              NaN
# 14934   Fennec Shand Key Chain       Gear     NaN      5.99              NaN
# 14935  Scout Trooper Key Chain       Gear     NaN      5.99              NaN
#
# [14936 rows x 5 columns]

# %% [markdown]
# #### 6. Use this column to find the top 10 most expensive sets by "price per piece"

# %%
lego_new.sort_values('price per piece', ascending= False)
# Out:
#                                                     Name  \
# 14251  LEGO Minifigures - Series 22 {Box of 6 random ...
# 13806  LEGO Minifigures - Marvel Studios Series {Box ...
# 13892                 Character Pack Series 3 - Complete
# 9653                               EV3 Intelligent Brick
# 7695                       Intelligent NXT Brick (Black)
# ...                                                  ...
# 14931                                  Creeper Key Chain
# 14932                                    Steve Key Chain
# 14933                                   Piglin Key Chain
# 14934                             Fennec Shand Key Chain
# 14935                            Scout Trooper Key Chain
#
#                          Theme  Pieces  USD_MSRP  price per piece
# 14251  Collectable Minifigures     0.0     29.94              inf
# 13806  Collectable Minifigures     0.0     29.94              inf
# 13892              Super Mario     0.0      4.99              inf
# 9653                Mindstorms     1.0    224.95           224.95
# 7695                Mindstorms     1.0    169.99           169.99
# ...                        ...     ...       ...              ...
# 14931                     Gear     NaN      5.99              NaN
# 14932                     Gear     NaN      5.99              NaN
# 14933                     Gear     NaN      5.99              NaN
# 14934                     Gear     NaN      5.99              NaN
# 14935                     Gear     NaN      5.99              NaN
#
# [14936 rows x 5 columns]

# %% [markdown]
# #### 7. Narrow the search to show the top 10 most expensive sets by "price per piece" for the "Icons" theme *only*

# %%
lego_new[lego_new['Theme'] == 'Icons'].sort_values('price per piece', ascending= False)
# Out:
#                                                     Name  Theme   Pieces  \
# 13941                                      Optimus Prime  Icons   1508.0
# 13943                         Chevrolet Camaro Z/28 1969  Icons   1456.0
# 13450                                        Porsche 911  Icons   1458.0
# 13440                         Adidas Originals Superstar  Icons    731.0
# 13939                    Back to the Future Time Machine  Icons   1872.0
# 13942                                       Loop Coaster  Icons   3756.0
# 14441                     Land Rover Classic Defender 90  Icons   2336.0
# 13446                         Queer Eye – The Fab 5 Loft  Icons    974.0
# 12940                                Ghostbusters ECTO-1  Icons   2352.0
# 13617                                Everyone is Awesome  Icons    346.0
# 13945                                         Atari 2600  Icons   2532.0
# 12939                                      Haunted House  Icons   3231.0
# 13937                                          Vespa 125  Icons   1106.0
# 13944                               Lion Knights' Castle  Icons   4514.0
# 13447                             The Friends Apartments  Icons   2048.0
# 13444                                   Bird of Paradise  Icons   1173.0
# 13442                       NASA Space Shuttle Discovery  Icons   2354.0
# 12941                                     Elf Club House  Icons   1197.0
# 13950                                             Orchid  Icons    608.0
# 13437                           Volkswagen T2 Camper Van  Icons   2207.0
# 14440                   The Lord of the Rings: Rivendell  Icons   6167.0
# 13951                                    Galaxy Explorer  Icons   1254.0
# 13438                                     Flower Bouquet  Icons    756.0
# 14436                                          Jazz Club  Icons   2899.0
# 12943                               Crocodile Locomotive  Icons   1271.0
# 13445                                       Pickup Truck  Icons   1677.0
# 13936                                     Boutique Hotel  Icons   3066.0
# 13449                                            Titanic  Icons   9090.0
# 13448                                      Santa's Visit  Icons   1445.0
# 13436                                     Police Station  Icons   2923.0
# 13938            Real Madrid - Santiago Bernabéu Stadium  Icons   5876.0
# 13947                                Holiday Main Street  Icons   1514.0
# 13948                                         Succulents  Icons    771.0
# 14437                                 Wildflower Bouquet  Icons    939.0
# 13443                            Camp Nou - FC Barcelona  Icons   5509.0
# 13946                                       Eiffel Tower  Icons  10001.0
# 14438                           Dried Flower Centrepiece  Icons    812.0
# 12942                                          Colosseum  Icons   9036.0
# 14576                                          Daffodils  Icons    216.0
# 13439                                        Bonsai Tree  Icons    878.0
# 13441  Adidas Originals Superstar X Footshop 'Bluepri...  Icons      NaN
# 13597                           FC Barcelona Celebration  Icons    178.0
# 13598                    Mini Adidas Originals Superstar  Icons     92.0
# 13940                                                {?}  Icons      NaN
# 13949                                                {?}  Icons      NaN
# 14086                                       Vintage Taxi  Icons    163.0
# 14117                                     Forest Hideout  Icons    258.0
# 14127                                 Eiffel's Apartment  Icons    228.0
# 14439                                                {?}  Icons      NaN
# 14539                                  Blacktron Cruiser  Icons    356.0
# 14540                            BIONICLE Tahu and Takua  Icons    219.0
# 14545                                       Moving Truck  Icons    301.0
#
#        USD_MSRP  price per piece
# 13941    179.99         0.119357
# 13943    169.99         0.116751
# 13450    169.99         0.116591
# 13440     79.99         0.109425
# 13939    199.99         0.106832
# 13942    399.99         0.106494
# 14441    239.99         0.102735
# 13446     99.99         0.102659
# 12940    239.99         0.102037
# 13617     34.99         0.101127
# 13945    239.99         0.094783
# 12939    299.99         0.092847
# 13937     99.99         0.090407
# 13944    399.99         0.088611
# 13447    179.99         0.087886
# 13444     99.99         0.085243
# 13442    199.99         0.084958
# 12941     99.99         0.083534
# 13950     49.99         0.082220
# 13437    179.99         0.081554
# 14440    499.99         0.081075
# 13951     99.99         0.079737
# 13438     59.99         0.079352
# 14436    229.99         0.079334
# 12943     99.99         0.078670
# 13445    129.99         0.077513
# 13936    229.99         0.075013
# 13449    679.99         0.074806
# 13448     99.99         0.069197
# 13436    199.99         0.068419
# 13938    399.99         0.068072
# 13947     99.99         0.066044
# 13948     49.99         0.064838
# 14437     59.99         0.063887
# 13443    349.99         0.063531
# 13946    629.99         0.062993
# 14438     49.99         0.061564
# 12942    549.99         0.060867
# 14576     12.99         0.060139
# 13439     49.99         0.056936
# 13441     79.99              NaN
# 13597       NaN              NaN
# 13598       NaN              NaN
# 13940       NaN              NaN
# 13949       NaN              NaN
# 14086       NaN              NaN
# 14117       NaN              NaN
# 14127       NaN              NaN
# 14439       NaN              NaN
# 14539       NaN              NaN
# 14540       NaN              NaN
# 14545       NaN              NaN

# %% [markdown]
# #### 8. What are the top 10 cheapest sets by "price per piece" in the "Icons" theme?

# %%
lego_new[lego_new['Theme'] == 'Icons'].sort_values('price per piece', ascending= True)
# Out:
#                                                     Name  Theme   Pieces  \
# 13439                                        Bonsai Tree  Icons    878.0
# 14576                                          Daffodils  Icons    216.0
# 12942                                          Colosseum  Icons   9036.0
# 14438                           Dried Flower Centrepiece  Icons    812.0
# 13946                                       Eiffel Tower  Icons  10001.0
# 13443                            Camp Nou - FC Barcelona  Icons   5509.0
# 14437                                 Wildflower Bouquet  Icons    939.0
# 13948                                         Succulents  Icons    771.0
# 13947                                Holiday Main Street  Icons   1514.0
# 13938            Real Madrid - Santiago Bernabéu Stadium  Icons   5876.0
# 13436                                     Police Station  Icons   2923.0
# 13448                                      Santa's Visit  Icons   1445.0
# 13449                                            Titanic  Icons   9090.0
# 13936                                     Boutique Hotel  Icons   3066.0
# 13445                                       Pickup Truck  Icons   1677.0
# 12943                               Crocodile Locomotive  Icons   1271.0
# 14436                                          Jazz Club  Icons   2899.0
# 13438                                     Flower Bouquet  Icons    756.0
# 13951                                    Galaxy Explorer  Icons   1254.0
# 14440                   The Lord of the Rings: Rivendell  Icons   6167.0
# 13437                           Volkswagen T2 Camper Van  Icons   2207.0
# 13950                                             Orchid  Icons    608.0
# 12941                                     Elf Club House  Icons   1197.0
# 13442                       NASA Space Shuttle Discovery  Icons   2354.0
# 13444                                   Bird of Paradise  Icons   1173.0
# 13447                             The Friends Apartments  Icons   2048.0
# 13944                               Lion Knights' Castle  Icons   4514.0
# 13937                                          Vespa 125  Icons   1106.0
# 12939                                      Haunted House  Icons   3231.0
# 13945                                         Atari 2600  Icons   2532.0
# 13617                                Everyone is Awesome  Icons    346.0
# 12940                                Ghostbusters ECTO-1  Icons   2352.0
# 13446                         Queer Eye – The Fab 5 Loft  Icons    974.0
# 14441                     Land Rover Classic Defender 90  Icons   2336.0
# 13942                                       Loop Coaster  Icons   3756.0
# 13939                    Back to the Future Time Machine  Icons   1872.0
# 13440                         Adidas Originals Superstar  Icons    731.0
# 13450                                        Porsche 911  Icons   1458.0
# 13943                         Chevrolet Camaro Z/28 1969  Icons   1456.0
# 13941                                      Optimus Prime  Icons   1508.0
# 13441  Adidas Originals Superstar X Footshop 'Bluepri...  Icons      NaN
# 13597                           FC Barcelona Celebration  Icons    178.0
# 13598                    Mini Adidas Originals Superstar  Icons     92.0
# 13940                                                {?}  Icons      NaN
# 13949                                                {?}  Icons      NaN
# 14086                                       Vintage Taxi  Icons    163.0
# 14117                                     Forest Hideout  Icons    258.0
# 14127                                 Eiffel's Apartment  Icons    228.0
# 14439                                                {?}  Icons      NaN
# 14539                                  Blacktron Cruiser  Icons    356.0
# 14540                            BIONICLE Tahu and Takua  Icons    219.0
# 14545                                       Moving Truck  Icons    301.0
#
#        USD_MSRP  price per piece
# 13439     49.99         0.056936
# 14576     12.99         0.060139
# 12942    549.99         0.060867
# 14438     49.99         0.061564
# 13946    629.99         0.062993
# 13443    349.99         0.063531
# 14437     59.99         0.063887
# 13948     49.99         0.064838
# 13947     99.99         0.066044
# 13938    399.99         0.068072
# 13436    199.99         0.068419
# 13448     99.99         0.069197
# 13449    679.99         0.074806
# 13936    229.99         0.075013
# 13445    129.99         0.077513
# 12943     99.99         0.078670
# 14436    229.99         0.079334
# 13438     59.99         0.079352
# 13951     99.99         0.079737
# 14440    499.99         0.081075
# 13437    179.99         0.081554
# 13950     49.99         0.082220
# 12941     99.99         0.083534
# 13442    199.99         0.084958
# 13444     99.99         0.085243
# 13447    179.99         0.087886
# 13944    399.99         0.088611
# 13937     99.99         0.090407
# 12939    299.99         0.092847
# 13945    239.99         0.094783
# 13617     34.99         0.101127
# 12940    239.99         0.102037
# 13446     99.99         0.102659
# 14441    239.99         0.102735
# 13942    399.99         0.106494
# 13939    199.99         0.106832
# 13440     79.99         0.109425
# 13450    169.99         0.116591
# 13943    169.99         0.116751
# 13941    179.99         0.119357
# 13441     79.99              NaN
# 13597       NaN              NaN
# 13598       NaN              NaN
# 13940       NaN              NaN
# 13949       NaN              NaN
# 14086       NaN              NaN
# 14117       NaN              NaN
# 14127       NaN              NaN
# 14439       NaN              NaN
# 14539       NaN              NaN
# 14540       NaN              NaN
# 14545       NaN              NaN

# %% [markdown]
# #### 9. Export the `DataFrame` you created in question 2. to a new CSV file.

# %%
lego_new.to_csv('legonew.csv', index= False)

# %% [markdown]
# ### Reflection
#
# What is your answer to the business question? Here it is as a reminder:
#
# > What is the biggest set we could build (in terms of number of pieces) and what sort of price would we want to charge?
#
# Reflect on your experience. How was working with `pandas` compared to other tools you already know?
