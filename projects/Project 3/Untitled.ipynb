# %%
import pandas as pd

# %%
test = pd.read_csv('./data/test.csv')

# %%
test
# Out:
#       Property_id Offer                                                URL  \
# 0            4394  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# 1            2338  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# 2            8531  Rent  https://www.propertyfinder.bh/en/plp/rent/comp...
# 3            8952  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# 4           11064  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# ...           ...   ...                                                ...
# 3522        13597  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# 3523         2475  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# 3524         2685  Rent  https://www.propertyfinder.bh/en/plp/rent/vill...
# 3525         2523  Rent  https://www.propertyfinder.bh/en/plp/rent/apar...
# 3526         2628  Rent  https://www.propertyfinder.bh/en/plp/rent/vill...
#
#      Property_type Include_w_e  \
# 0        Apartment   Inclusive
# ...

# %%
test.isnull().sum()
# Out:
# Property_id            0
# Offer                  0
# URL                    0
# Property_type          0
# Include_w_e            0
# Title                  0
# Area                   0
# Governorate            0
# Beds                   0
# Baths                  0
# Size                   0
# Availability_date    168
# Agent_name             0
# Agency                 0
# Amenities             86
# dtype: int64
